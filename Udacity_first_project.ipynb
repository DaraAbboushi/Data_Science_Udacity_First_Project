# %% [markdown]
# # How will data convince you that Data Science is worth the effort?
#
# By Dara Abboushi:

# %% [markdown]
# ![Data-Science-Career-Path.jpg](attachment:194768df-42d0-45bc-9a68-8ac16b2ad8ab.jpg)

# %% [markdown]
# The image was found on google.

# %% [markdown]
# # Introduction:
#
# For this Udacity project, i decided to work on the Data Science Salaries of 2024 dataset. This dataset can be found on Kaggle website using this url: https://www.kaggle.com/datasets/saurabhbadole/latest-data-science-job-salaries-2024/data
# For this project, i followed the CRISP-DM Process which implies 6 significant rules:
#
# 1) Business Understanding
# 2) Data Understanding
# 3) Preparing Data
# 4) Modelling the Data
# 5) Evaluating the Results
# 6) Deployment

# %% [markdown]
# # Business Understanding:
#
# As a result of the Techonology evolution and the wide expansion of companies all over the world, the data science field is required more than ever. Varitey of busninesses and companies are in need for data scientists' hands and minds to deal with Data from different sources to make actionable effective decisions for better judgement calls regarding companies. Data scienctists are spread out in various sector domains such as, healthcare, finance, marketing, banking, Automation and much more. They collect and process data to investigate trends, correlations and to build efficient algorithmic models that can make better data-driven insights. It has been reproted that the growth of data science jobs sector has been growning exponentially since 2021, and is predicted to grow even more till 2031 by 36%, much more faster than the average of all occupations according to the Bureau of Labor Statistics (BLS). For these reasons, it is vital to know indifferent to the company sizes especially large companies that without data science, companies would have a severe difficulty in dealing with data. Data science have the power to extract the hidden stories and messages that the data wants to tell us. So if we use the tools well, we can build smarter  data-driven decisions models. Data Science can be very challenging to learn, however with presistence and patience, it can be rewarding and fulfilling.
#
#
# In this project, we are going to process, clean, visualize and analyse data to answer the questions that would hold insightful information about the importance of Data Science Jobs that anyone who is just starting out needs to know about, like myself (a beginner).
#
#
# Let us begin with the following questions:
#
# 1) What is the most dominant level of job experience in the Data Science career field?
# 2) What are the top 10 jobs that have been in high demand in the job market?
# 3) Do level of experience(in jobs) vary in salary and did the salary increase or decrease along the years of 2020-2024 depending on experience level (a follow-up question and not an extra one)?
# 4) Does the size of the company have an effect on whether the salary is high or low for employees?
# 5) Does the job title have an effect on whether the salary is high or low for employees and how does that relate to the company size?

# %% [markdown]
# # Importing libraries and reading files:
#
# I imported 4 libraries:
# Pandas & Numpy for data manipulation and wrangling.
# Matplotlib and Seaborn for data visualisation & analysis.

# %%
# %pip install seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb


# %matplotlib inline

salaries = pd.read_csv('DataScience_salaries_2024.csv')

# %%
#a quick display for the dataset 
salaries.head(10)
# Out:
#    work_year experience_level employment_type                       job_title  \
# 0       2021               MI              FT                  Data Scientist
# 1       2021               MI              FT                 BI Data Analyst
# 2       2020               MI              FT                  Data Scientist
# 3       2021               MI              FT                     ML Engineer
# 4       2022               SE              FT  Lead Machine Learning Engineer
# 5       2021               MI              FT                     ML Engineer
# 6       2021               SE              FT            Data Science Manager
# 7       2022               EN              FT                  Data Scientist
# 8       2022               EX              FT        Head of Machine Learning
# 9       2022               EN              FT               Research Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %% [markdown]
# # Assess and Prepare data:
#
# I Prepared and provided info regarding the dataset under each result, in addition to the comments in my code explaining the steps and the functions.
#
# As we can see from the graph above that the table has 14838 rows × 11 columns.
#
# To make the dataset more clearer, i will explain each column and what they contain:
#
# 0) Index: a numbering column beside the work_year column to the left that starts from 0-till the end.
# It is not part of the dataset, however since it has been read as a DataFrame, it appears automatically. It can be seen in the graph below.
#
# 2) work_year: The year of the data related to the job salary.
# 3) experience_level: The level of experience of the employee (e.g., Junior, Mid-level, Senior, Executive).
# 4) employment_type: The type of employment (e.g., Full-Time, Part-Time, Contract).
# 5) job_title: The title or role of the employee within the data science field.
# 6) salary: The salary of the employee.
# 7) salary_currency: The currency in which the salary is denoted.
# 8) salary_in_usd: The salary converted to US dollars for standardization.
# 9) employee_residence: The residence location of the employee.
# 10) remote_ratio: The ratio of remote work allowed for the position.
# 11) company_location: The location of the company.
# 12) company_size: The size of the company based on employee's income.

# %%
# The sample function provides random 5 rows of the table regarding each column and observation. The number in brackets of the function can be changed if wanted. 
salaries.sample(5)
# Out:
#        work_year experience_level employment_type       job_title  salary  \
# 5342        2023               SE              FT   Data Engineer  166000
# 5041        2023               SE              FT  Data Scientist  170000
# 14634       2023               SE              FT  Data Scientist   36000
# 2190        2024               SE              FT  Data Scientist  218750
# 5851        2023               SE              FT   Data Engineer  160000
#
#       salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 5342              USD         166000                 US           100
# 5041              USD         170000                 US             0
# 14634             EUR          38868                 ES             0
# 2190              USD         218750                 US             0
# 5851              USD         160000                 US           100
#
#       company_location company_size
# 5342                US            M
# ...

# %% [markdown]
# The sample function provides the first 5 random rows of the table regarding each column and observation.

# %%
#the shape function gives the full number of rows and columns of the dataset, i used it to provide info about the dataset.
print('The dataset has a shape of {}'.format(salaries.shape))
# Out:
# The dataset has a shape of (14838, 11)

# %% [markdown]
# Counting the rows and columns in the dataset and returning it in a tuple

# %%
#to gain more info about our dataset we can use info function
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14838 entries, 0 to 14837
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           14838 non-null  int64
#  1   experience_level    14838 non-null  object
#  2   employment_type     14838 non-null  object
#  3   job_title           14838 non-null  object
#  4   salary              14838 non-null  int64
#  5   salary_currency     14838 non-null  object
#  6   salary_in_usd       14838 non-null  int64
#  7   employee_residence  14838 non-null  object
#  8   remote_ratio        14838 non-null  int64
#  9   company_location    14838 non-null  object
#  10  company_size        14838 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 869.5+ KB

# %% [markdown]
# The info function prints helpful information about the DataFrame to get to know the dataset better before we begin cleaning.

# %%
#describe function provides a summary statistics about the dataset.
salaries.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  14838.000000  1.483800e+04   14838.000000  14838.000000
# mean    2023.138900  1.650227e+05  149874.718763     32.760480
# std        0.700799  3.562354e+05   69009.181349     46.488278
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2023.000000  1.021000e+05  102000.000000      0.000000
# 50%     2023.000000  1.422000e+05  141300.000000      0.000000
# 75%     2024.000000  1.875000e+05  185900.000000    100.000000
# max     2024.000000  3.040000e+07  800000.000000    100.000000

# %% [markdown]
# The describe function can be used for numeric and non-numeric objects while providing the necessary info for each of them.
# Here for the salaries dataset, we have four columns by wich salary and remote ratio are not going to be tested in this project nonetheless i will not remove them. Here we will focus on work year and salary_in_usd variables. In salary_in_usd we can see that its minimum salary is 15000 in 2020 and its maximum salary is 800000 in 2024.

# %% [markdown]
# # Clean data:

# %% [markdown]
# Check for any missing values, rename columns, and change variable's names.

# %%
#to check for any NaN values(missing values) so we can either remove them or discover more about them.
salaries.isnull()
# Out:
#        work_year  experience_level  employment_type  job_title  salary  \
# 0          False             False            False      False   False
# 1          False             False            False      False   False
# 2          False             False            False      False   False
# 3          False             False            False      False   False
# 4          False             False            False      False   False
# ...          ...               ...              ...        ...     ...
# 14833      False             False            False      False   False
# 14834      False             False            False      False   False
# 14835      False             False            False      False   False
# 14836      False             False            False      False   False
# 14837      False             False            False      False   False
#
#        salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# ...

# %%
#to make sure that there no missing values 
salaries.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# In this dataset, we can see that there are no missing values in any column to deal with which is a very good thing  because it is difficult to decide if removing is the right choice, it can mess up our understanding of the data and our calculations.

# %%
#I replaced some of the column's variables into other names so it can be easily understood and read by others

salaries['experience_level'].replace({'MI': 'Mid-level', 'SE': 'Senior', 'EN': 'Junior', 'EX': 'Executive'}, inplace=True)
salaries['company_size'].replace({'M': 'Medium', 'S': 'Small', 'L': 'Large'}, inplace=True)
salaries['employment_type'].replace({'FT': 'Full Time', 'PT': 'Part Time', 'C': 'Contract'}, inplace=True)


salaries.head(5)
# Out:
#    work_year experience_level employment_type                       job_title  \
# 0       2021        Mid-level       Full Time                  Data Scientist
# 1       2021        Mid-level       Full Time                 BI Data Analyst
# 2       2020        Mid-level       Full Time                  Data Scientist
# 3       2021        Mid-level       Full Time                     ML Engineer
# 4       2022           Senior       Full Time  Lead Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  30400000             CLP          40038                 CL           100
# 1  11000000             HUF          36259                 HU            50
# 2  11000000             HUF          35735                 HU            50
# 3   8500000             JPY          77364                 JP            50
# 4   7500000             INR          95386                 IN            50
#
#   company_location company_size
# ...

# %% [markdown]
# I renamed some of the column's variables to make everything clear and easier to comprehend:
#
# Firstly, for experience_level column:
# 1) MI- Mid-level
# 2) SE- Senior
# 3) EN- Junior
# 4) EX- Executive
# 5)
# Secondly, for company_size column:
# 1) M- Medium
# 2) S- Small
# 3) L- Large
#
# Lastly, for employment_type column:
# 1) FT- Full Time
# 2) PT- Part Time
# 3) C- Contract

# %%
type_counts = salaries['job_title'].value_counts()
type_counts
# Out:
# Data Engineer                      3162
# Data Scientist                     3015
# Data Analyst                       2189
# Machine Learning Engineer          1542
# Research Scientist                  475
#                                    ...
# Deep Learning Researcher              1
# Big Data Developer                    1
# AWS Data Architect                    1
# Staff Machine Learning Engineer       1
# CRM Data Analyst                      1
# Name: job_title, Length: 153, dtype: int64

# %% [markdown]
# We can see from the values count function that the most dominant jobs across the 4 years are of the data engineer scoring 3162 counts and data scientist scoring 3015 counts compared with decreasing number below them. It is a fundemental thing to know considering which jobs in the market are mostly abundant and what people get in this sector for. This will be investigated closely when we start visualsing and analyzing plots to answer questions. The count function starts from top counts to the least counts.

# %% [markdown]
# # Exploratory Data Analysis:
# Data Visualisation and Analysis:
#
# There are 5 questions along their visuals.
#
# Below each visual i added an explanation of the methods i used and an analysis of the plot's results in brief. Additionally, i added comments in my code and explained what i did and for what.

# %% [markdown]
# 1-What is the most dominant level of job experience in the Data Science career field?

# %%
#i used the value count function to count the numbers of each category since its non-numeric object.
level_types = salaries['experience_level'].value_counts()
level_types
# Out:
# Senior       9696
# Mid-level    3553
# Junior       1148
# Executive     441
# Name: experience_level, dtype: int64

# %%
#i also specified the font size of words printed on the pie chart
plt.rcParams['font.size'] = 7
#for the colors of the pie chart
cl = ['orange', 'red', 'pink', 'yellow']
plt.pie(level_types, labels = level_types.index, startangle = 90, autopct = '%2.2f%%', colors=cl)
plt.axis('square')
plt.xlabel('Job Experience Levels')
# Out:
# Text(0.5, 0, 'Job Experience Levels')

# %% [markdown]
# Analysis: The reason behind using the pie chart to visualize experience level categories even though it is well known that such charts can give misleading information when dealing with many categories is that the number of categories is small.
# Now back to the pie chart, the graph shows that from 2020-2024 the most people who work in the Technology field are mostly of senior experience (65.35% from the whole) across a variety of jobs from 2020-2024, followed by Mid-level of 23.95%.
#
#
# Let's go to the second question:

# %% [markdown]
# 2-What are the top 10 jobs that have been in high demand in the job market?

# %%
job_type = salaries['job_title'].value_counts()[:10]

job_type
# Out:
# Data Engineer                     3162
# Data Scientist                    3015
# Data Analyst                      2189
# Machine Learning Engineer         1542
# Research Scientist                 475
# Analytics Engineer                 403
# Applied Scientist                  383
# Data Architect                     369
# Research Engineer                  276
# Business Intelligence Engineer     230
# Name: job_title, dtype: int64

# %%
# we are going to get the frequency for each job type to change the x-ticks and get them printed on the graph to make things clear!
n_types = salaries['job_title'].value_counts().sum()
#get the hgihest number of them 
max_job_type = job_type.shape[0]
#we get the max_prop for the xticks 
max_prop = max_job_type/n_types
#now we create an array to loop through it
tick_props = np.arange(0, max_prop+0.22, 0.01)
#make of the array, a text of each proportion in a list looped through it
tick_names = ['{:0.2f}'.format(i) for i in tick_props]

# %%
#we will print the frquency numbers of each job title on the graph
plt.rcParams['font.size'] = 6
sb.countplot(data= salaries, y='job_title', order=job_type.index)

for i in range(job_type.shape[0]):
    count = job_type[i]
    pct_string = '{:0.2f}'.format(count*100/n_types)
    plt.text(count+1, i, pct_string, va='center')

plt.xticks(tick_props * n_types, tick_names)
plt.xlabel('Proportion')
# Out:
# Text(0.5, 0, 'Proportion')

# %% [markdown]
# Explanation: I used a bar chart to map the top 10 level jobs(categorical variable) alongside their proportion values in the dataset.
#
# Analysis: From the bar graph, it can be seen that Data Engineer, Data scientist, Machine Learning Engineer and Data Analyst are the most demanding jobs in the Data Science job sector which is not surprising at all. It is known the data science field has been dominating the job market for years.

# %% [markdown]
# 3- Do level of experience(in jobs) vary in salary and did the salary increase or decrease along the years(2020-2024) depending on experience level (a follow-up question and not an extra one)?

# %%
plt.rcParams['font.size'] = 8
sb.barplot(data=salaries, x='work_year', y='salary_in_usd', hue= 'experience_level')
# Out:
# <AxesSubplot:xlabel='work_year', ylabel='salary_in_usd'>

# %% [markdown]
# Explanation: The graph depicts the relationship of 3 variables, one is numeric varaible(salary) and two categorical variables(year, experience levels). This clustered bar graph depicts the number of salary of each experience level in each year. I wanted to see if level of experiences in salary changed for the better in terms of a junior or mid-level employee. I also added an error bar to reveal the variability of data and uncertainty of data points. To make it even more clearer, a short error depicts that values are concentrated and not spread out, demonstrating that the average of the bar is reliable. However in the case of a long error bar, the values are spread out and less likely to be trusted. I thought it would be significant to report the error bars instead of deleting or ignoring them.
#
# Analysis: Somewhat surprisingly, the number of salaries in each group accross the years increase gradually. The graph demoenstaters that a junior employee earns the least one of the 4 levels, however astonishingly, mid and senior level of experience's salaries were not far from each other in 2023 and 2024 and the same thing can be concluded about the executive and senior employees. We can see that the executive, senior, junior, and mid-level bars chart in 2020 and 2021, the error bar is very spread out and the plotted average is less likely to be trusted. However the rest of the error bars values are quite reasonable to be trusted. To be cautious in interpreting, earning money does depend on the level of experience, however it also depends on the location of the company employees work in and the size of company as depicted below.

# %% [markdown]
# 4- Does the size of the company have an effect on whether the salary is high or low for employees?

# %%
plt.rcParams['font.size'] = 11
sb.boxplot(data=salaries, x= 'company_size', y= 'salary_in_usd') #you should try doing it with a sample or with facetgrid
# Out:
# <AxesSubplot:xlabel='company_size', ylabel='salary_in_usd'>

# %% [markdown]
# Explanation: I wanted to have a closer look on what salary might depend on, if its high and low levels depend on whether the company is small or large. Which is why i mapped the box plot because it can depict the minimum, maximum, median levels and whether the distribution of dataset is normal or not and most importantly to check for outliers values.
#
# Analysis: first of all, the minimum values of salary are nearly the same in all the sizes of companies. The median is least in small company which indicates that the salary in general is not high while the salary is nearly equal between large and medium companies but higher in medium sized companies which might be explained by the many outliers in high salary that medium sized companies have. Thirdly, the maximum number of salary is higher in larger companies than with the two sized companies. As shown in the graph there are many high salary outliers compared with other two, which might indicate that working at a medium or large company alone doesn't guarantee a higher salary because the salary also depends on the job title and the experience.

# %% [markdown]
# 5- Does the job title have an effect on whether the salary is high or low for employees and how does that relate to the company size?

# %%
#i copied the the original dataset to work on it seperately without making changes to the original one.
df = salaries.copy()
#By specifying a seed value, the function makes sure that the produced sequence of random numbers remain the same for multipule runs.
np.random.seed(8000)
#i set a sample of 4000 observation to be chosen from randomly that comply with a number of jobs of my choice(i chose them randomly)
sample = np.random.choice(df.shape[0], 4000, replace= False)

# to make the subset i had to use .loc which is typically used for label indexing, loc object returns the 4000 rows and its associated columns from that DataFrame
jobs_subset = df.loc[sample]

# job titles in a list 
jobs = ['Data Engineer',
 'Data Scientist',
 'Data Analyst',
 'Machine Learning Engineer',
 'Research Engineer',
 'Applied Scientist',
 'Business Intelligence Engineer',
 'Analytics Engineer',
 'Research Scientist',
 'Principal Data Scientist',
 'Data Manager',
 'Data Architect',
 'Research Analyst',
 'Decision Scientist',
 'Machine Learning Scientist',
 'Business Intelligence Analyst',
 'Data Developer']

#let us visualise the subset
jobs_subset
# Out:
#        work_year experience_level employment_type  \
# 10089       2023           Senior       Full Time
# 9109        2023           Senior       Full Time
# 4590        2024           Senior       Full Time
# 4560        2022           Senior       Full Time
# 9905        2024           Senior       Full Time
# ...          ...              ...             ...
# 9613        2023           Senior       Full Time
# 13072       2023        Mid-level       Full Time
# 2340        2023           Senior       Full Time
# 7396        2023           Senior       Full Time
# 7852        2023           Senior       Full Time
#
#                              job_title  salary salary_currency  salary_in_usd  \
# 10089                    Data Engineer  115000             USD         115000
# 9109                Research Scientist  127300             USD         127300
# 4590         Machine Learning Engineer  175000             USD         175000
# ...

# %%
# it gives back ordered catgorical types of jobs
job_classes = pd.api.types.CategoricalDtype(ordered=True, categories=jobs)

# # I used pandas.astype() function to convert the the job_title column in the subset into an ordered categorical type
jobs_subset['job_title'] = jobs_subset['job_title'].astype(job_classes)

# I used group_by() and size() to get the number of job types and each combination of the two variable levels as a pandas Series
ct_counts = jobs_subset.groupby(['job_title', 'experience_level']).size()

# I used reset_index() to the series in the code above to convert a series into a dataframe object
ct_counts = ct_counts.reset_index(name='count')

# I used DataFrame.pivot() to rearrange the data, to have job titles on rows
ct_counts = ct_counts.pivot(index = 'job_title', columns = 'experience_level', values = 'count')

#i set the size of the white space for the figures to be set side by side
plt.figure(figsize=[23,5])
plt.subplot(1,2,1)
sb.boxplot(data = jobs_subset, x = 'job_title', y = 'salary_in_usd')
plt.xticks(rotation= 90)
plt.rcParams['font.size'] = 6

plt.subplot(1,2,2)

ct_counts = jobs_subset.groupby(['job_title', 'company_size']).size()
ct_counts = ct_counts.reset_index(name='count')
ct_counts = ct_counts.pivot(index = 'job_title', columns = 'company_size', values = 'count')
ct_counts
sb.heatmap(ct_counts, annot = True, fmt = 'd')
# Out:
# <AxesSubplot:xlabel='company_size', ylabel='job_title'>

# %% [markdown]
# Explanation: Firstly, i chose a list of job titles contained in a list(code above) in order to map their salaries across the years indifferent to their experience level. Secondly, to avoid over plotting i set a sample of 4000 observations to be chosen from randomly but which comply with the chosen list of job titles. Thirdly, i mapped subplots side by side in order to infer to the 4th question and to explain why outliers might have occurred. Fourthly, i did not remove the outliers for that it might tell us something important and that's why i wanted to investigate it by mapping subplots side by side.
#
# Analysis: There are many observations that one can conclude from these subplots: Firstly, the left subplot shows 50% of jobs that are enlisted in the graph, their maximum salary ranges between 280000 and 400000 usd while 50% of their average salary is above 100000. Secondly, more than a half of the jobs(in the graph) minimum is under 100000. Thirdly, there are extremely high salaries(outliers) in some jobs that are above the job's maximum salary especially in the data scientist job. Fourthly, in the right subplot, the graph depicts that all the jobs specifically Data scientist, Data Engineer, Data Analyst and Machine Learning Engineer work mostly in medium sized companies and large sized companies in comparison to small companies. The outliers found in the graph above might be explained by this heat map graph, by which the outliers for extremely high number of salaries above their maximum number work in medium companies. As a result, the job title and the company size matter has an effect in getting higher salary.

# %% [markdown]
# # Communicating my Insights with Stakeholders:
# My Medium blog post: https://medium.com/@daraabboushi22/how-will-data-convince-you-that-a-career-in-data-science-is-worth-the-effort-ad019e36cb3f

# %% [markdown]
# # Conclusion:

# %% [markdown]
# We can conclude 5 points regarding each question:
#
# 1- From 2020-2024 we can conclude that most people who work in the Data Science field are mostly of senior experience.
#
# 2- The most demanding jobs in Data Science sector are: Data Engineer, Data scientist, Machine Learning Engineer and Data Analyst.
#
# 3- A junior employee earns the least of the experience levels, however mid and senior's salary weren't far from each other in 2023 and 2024.
#
# 4- The average of the salary is earned the least in small companies while in large and medium companies the salary in them both are higher.
#
# 5- 50% of Data science jobs that are shown in the 5th question, receive a maximum salary which ranges between 280000 and 400000 USD.

# %% [markdown]
# # Refrenece
# 1) https://www.codingdojo.com/blog/why-study-data-science
